# %%
import cv2
import matplotlib.pyplot as plt
import easyocr

# %%
path = 'img\\image4.jpg'
img = cv2.imread(path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_rgb)
plt.axis('off')
# Out:
# (-0.5, 1001.5, 1279.5, -0.5)

# %%
reader = easyocr.Reader(['id'])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
# Melakukan OCR pada gambar
results = reader.readtext(path)

# Menampilkan hasil OCR
for (bbox, text, prob) in results:
    print(f"Text: {text}, Probability: {prob:.4f}")
# Out:
# Text: informasi NiLAI GiZI / NuTRITION FACTS, Probability: 0.2148
# Text: Takaran Saji, Probability: 0.5504
# Text: Svze : 200 ml, Probability: 0.2684
# Text: Sajan per Kemasan, Probability: 0.8947
# Text: per, Probability: 0.6121
# Text: Jumlak Per Sajian / Amount Per serving, Probability: 0.1637
# Text: Total / Total , Probability: 0.6812
# Text: 120 Kkal/ kcal, Probability: 0.2244
# Text: 96 Akg' /808, Probability: 0.0312
# Text: Total / Total Fat, Probability: 0.8890
# Text: 259, Probability: 0.8464
# Text: Lemak Jenuh / Saturated Fat, Probability: 0.8543
# Text: 259, Probability: 0.8661
# Text: 135, Probability: 0.3151
# Text: 1 Bna, Probability: 0.0668
# Text: 10, Probability: 0.5420
# Text: 28, Probability: 0.1575
# Text: Total / Total Carbohydrate, Probability: 0.4891
# Text: 299, Probability: 0.2431
# Text: 78, Probability: 0.2850
# Text: Flber, Probability: 0.9762
# Text: 49, Probability: 0.9092
# Text: 148, Probability: 0.2289
# Text: 7, Probability: 0.6650
# Text: 189, Probability: 0.8142
# Text:  (Natrlum) / Salt (Sodlum), Probability: 0.7691
# Text: 105m9, Probability: 0.6540
# Text: 74, Probability: 0.1677
# Text: AKG berdasarkan Aebutuhan energi 2150 Mal, Probability: 0.6132
# Text: mungkin leblh tinggi atau lebth rendah:, Probability: 0.2734
# Text: Volues ate based on 0 2150 calorie diet Your daue, Probability: 0.1622
# Text: maybe higher or lower depending on your_, Probability: 0.4324
# Text: n, Probability: 0.0249
# Text: n, Probability: 0.1633
# Text: Konl Instan, Probability: 0.2408
# Text: Sewing, Probability: 0.5002
# Text: Serving [, Probability: 0.2366
# Text: Package, Probability: 0.5279
# Text: Energl, Probability: 0.8473
# Text: Encrgy, Probability: 0.6611
# Text: lemak, Probability: 0.7626
# Text: Proteln, Probability: 0.9156
# Text: Karbohldrat, Probability: 0.9543
# Text: Serat ,, Probability: 0.2096
# Text: Pangan, Probability: 0.9997
# Text: Dletary, Probability: 0.7703
# Text: Gula, Probability: 0.9672
# Text: 'Sua, Probability: 0.2123
# Text: Garam, Probability: 0.9688
# Text: 'Pensen, Probability: 0.2433
# Text: Kebutunan, Probability: 0.6929
# Text: energl_, Probability: 0.1837
# Text: Anda, Probability: 0.6978
# Text: "Percent', Probability: 0.1240
# Text: Dally, Probability: 0.9454
# Text: volues, Probability: 0.8394
# Text: Ga, Probability: 0.0662
# Text: calone, Probability: 0.4341
# Text: Homgoa , Probability: 0.0446
